# %% [markdown]
# # Introducción a estadística

# %%
import pandas as pd

# %%
data_houses=pd.read_csv('kc_house_data.csv')

# %% [markdown]
# ### 1) Estadística descriptiva
#
# Video AE3

# %%
from pandas_profiling import ProfileReport
# describir los datos

from funpymodeling.exploratory import status, profiling_num, freq_tbl

# %% [markdown]
# [Video intro a funpymodeling](https://www.youtube.com/watch?v=1wwQ9mWxrVE)

# %%
status(data_houses)
# Out:
#          variable  q_nan  p_nan  q_zeros   p_zeros  unique     type
# 0              id      0    0.0        0  0.000000   21420    int64
# 1            date      0    0.0        0  0.000000     372   object
# 2           price      0    0.0        0  0.000000    3622  float64
# 3        bedrooms      0    0.0        0  0.000000      12    int64
# 4       bathrooms      0    0.0        0  0.000000      29  float64
# 5     sqft_living      0    0.0        0  0.000000    1034    int64
# 6        sqft_lot      0    0.0        0  0.000000    9776    int64
# 7          floors      0    0.0        0  0.000000       6  float64
# 8      waterfront      0    0.0    21434  0.992453       2    int64
# 9            view      0    0.0    19475  0.901746       5    int64
# 10      condition      0    0.0        0  0.000000       5    int64
# 11          grade      0    0.0        0  0.000000      11    int64
# 12     sqft_above      0    0.0        0  0.000000     942    int64
# ...

# %%
freq_tbl(data_houses.price)
data_houses.price.hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Comparemos las popularidades! ¿Cuales son los zipcode más caros?

# %%
data_houses.groupby('zipcode')['price'].mean().sort_values(ascending=False)
# Out:
# zipcode
# 98039    2.161300e+06
# 98004    1.356524e+06
# 98040    1.194874e+06
# 98112    1.096239e+06
# 98102    8.996077e+05
#              ...
# 98148    2.849086e+05
# 98001    2.811949e+05
# 98032    2.512962e+05
# 98168    2.403284e+05
# 98002    2.342840e+05
# Name: price, Length: 70, dtype: float64

# %% [markdown]
# ¿Cuáles son los 5 temas más populares?

# %%
data_houses.sort_values('price', ascending=False).head()
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407  2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7245     27600     2.5           0     3  ...     13        8570
# 3910     37325     2.0           1     2  ...     11        7680
# 9245     31374     2.0           0     4  ...     13        8860
# 4407     35069     2.0           0     0  ...     13        6200
# 1446     23985     2.0           0     4  ...     12        6720
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# Ejercicio: Al set de datos anterior, quedarse con la combinación única de `id` y `zipcode`.

# %% [markdown]
# ¿Cuales son los zipcode que mas aparecen? (con duplicados...)

# %%
data_houses.groupby('zipcode').mean().sort_values('price', ascending=True).head()
# Out:
#                    id          price  bedrooms  bathrooms  sqft_living  \
# zipcode
# 98002    4.850894e+09  234284.035176  3.326633   1.839196  1627.743719
# 98168    3.204785e+09  240328.371747  2.996283   1.433086  1468.624535
# 98032    4.548921e+09  251296.240000  3.392000   1.708000  1738.048000
# 98001    4.651274e+09  281194.869806  3.393352   2.011773  1903.783934
# 98148    5.579459e+09  284908.596491  3.140351   1.793860  1610.526316
#
#              sqft_lot    floors  waterfront      view  condition     grade  \
# zipcode
# 98002     7517.633166  1.334171         0.0  0.010050   3.743719  6.693467
# 98168    11269.843866  1.159851         0.0  0.014870   3.245353  6.509294
# 98032    10379.760000  1.220000         0.0  0.080000   3.632000  7.144000
# 98001    14967.002770  1.430748         0.0  0.102493   3.335180  7.296399
# 98148     8960.719298  1.210526         0.0  0.000000   3.070175  6.947368
#
# ...

# %%
freq_track=freq_tbl(data_spotify['price'])
freq_track
#
# Out:
# 'No categorical variables to analyze.'

# %% [markdown]
# ## 2) Estadística inferencial

# %% [markdown]
# Video AE3

# %% [markdown]
# ### 2.1) Muestras de una población (intuición)

# %%
muestra_1=data_houses.sample(n=20000, random_state=1)
muestra_2=data_houses.sample(n=20000, random_state=2)
muestra_3=data_houses.sample(n=20000, random_state=3)

# %%
muestra_1.price.mean()
# Out:
# 541077.0755

# %%
muestra_2.price.mean()
# Out:
# 539048.73265

# %%
muestra_3.price.mean()
# Out:
# 540445.2741

# %%
muestra_1  # TR
muestra_2  # TS
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 570    5104510270   7/18/2014   338900.0         4       2.50         1830
# 19700  3943600070   8/11/2014   400000.0         3       2.50         2393
# 13482  8563030330   3/13/2015   565000.0         4       1.75         2030
# 11504  3179101070   6/30/2014   880000.0         4       2.75         3220
# 18868  1568100220    9/8/2014   350000.0         3       1.00         1010
# ...           ...         ...        ...       ...        ...          ...
# 18211   259801140  12/12/2014   451000.0         4       1.75         1680
# 9333   5018200155   1/21/2015   340000.0         3       1.75         2230
# 20401  9265880040    5/9/2014   557000.0         4       2.50         2840
# 6946   4139500080   7/18/2014  1490000.0         4       4.25         5180
# 18821  2485000100   5/29/2014   685000.0         3       1.75         1940
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ### 2.2) ¿Que pasa cuando la muestra baja mucho?

# %%
muestra_4=data_spotify.sample(n=100, random_state=1)
muestra_5=data_spotify.sample(n=100, random_state=2)
muestra_6=data_spotify.sample(n=100, random_state=3)

# %%
muestra_4.price.mean()
# Out:
# 477564.59

# %%
muestra_5.price.mean()
# Out:
# 506100.72

# %%
muestra_6.price.mean()
# Out:
# 568550.49

# %% [markdown]
# En la muestra 6 hay un **desvío de casi el 10%!**

# %% [markdown]
# ¿Cuántos datos necesito para hacer un modelo predictivo?

# %% [markdown]
# #### Dos tipos de muestras:
#
# - Muestras independientes
# - Muestras relacionadas
